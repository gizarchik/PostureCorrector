# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('metrics_data.csv', index_col='_id')
person = pd.read_csv('../person.csv', index_col='_id')

# %%
data
# Out:
#            x_mean        x_std    x_max    x_min       y_mean        y_std  \
# _id
# 1    13110.861519  1489.074033  17584.0    628.0  -231.045310  1249.368959
# 2    10398.993311   636.795316  11924.0   8728.0  1220.230769   712.538755
# 3    12969.669749   807.711275  15236.0  10760.0   -36.354029  1327.785100
# 6    12765.113725  3289.505788  29072.0   6396.0   815.027451  2927.223542
# 7    15146.131868   160.385778  16424.0  12984.0 -1865.611722   122.331084
# ..            ...          ...      ...      ...          ...          ...
# 307  15784.175413   291.910508  17200.0  14204.0  -675.847592   819.859282
# 308  15282.539857  3387.421937  27404.0   8024.0  -610.390324  1745.136557
# 309  14337.600584   197.941923  15764.0  12352.0  -675.310697   332.853723
# 310  15800.594937   261.708128  18100.0  13532.0  -641.810127   539.895303
# 311  14979.542553  3330.229010  25580.0   8564.0  -920.540426  1479.689278
#
# ...

# %%
person
# Out:
#      height  mass  position  is_valid  age  sex
# _id
# 1       180    85         2         0   18    1
# 2       185    75         1         0   18    1
# 3       185    75         2         0   18    1
# 6       185    75         3         0   18    1
# 7       185    75         1         1   18    1
# ..      ...   ...       ...       ...  ...  ...
# 307     170    61         2         0   20    0
# 308     170    61         3         0   20    0
# 309     170    61         1         1   20    0
# 310     170    61         2         1   20    0
# 311     170    61         3         1   20    0
#
# [128 rows x 6 columns]

# %%
pos1_idx = person[person['position'] == 1].index
pos23_idx = person[~(person['position'] == 1)].index

# %%
pos1 = data.loc[pos1_idx].copy()
pos23 = data.loc[pos23_idx].copy()

# %%
pos1.columns = list(map(lambda x: x + '_pos1', data.columns))
