# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn.metrics

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.multiclass import OneVsOneClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import classification_report

from tqdm import tqdm

from collections import defaultdict
from collections import OrderedDict

import time
import timeit

import json

# %matplotlib inline
sns.set(style='darkgrid', font_scale=1.5)

# %%
def plot_acc_and_time(history, sorted_metrics):
    plt.figure(figsize=(16, 10))
    plt.plot(
        np.arange(5, len(sorted_metrics)),
        history['accuracy']
    )
    plt.title("График зависимости Accuracy от числа метрик")
    plt.xlabel("Число метрик")
    plt.ylabel("Accuracy")
    plt.show()

    plt.figure(figsize=(16, 10))
    plt.plot(
        np.arange(5, len(sorted_metrics)),
        history['time_predict']
    )
    plt.title("График зависимости времени предсказания от числа метрик")
    plt.xlabel("Число метрик")
    plt.ylabel("Время предсказания, с")
    plt.show()

# %%
sorted_metrics = ['z_mean',
 'y_mean',
 'z_energy',
 'x_mean_pos1',
 'y_energy',
 'sma',
 'z_min',
 'y_min_pos1',
 'x_min_pos1',
 'x_energy',
 'y_mean_pos1',
 'y_max_pos1',
 'x_mean',
 'mass',
 'y_iqr_pos1',
 'y_min',
 'xz_corr_pos1',
 'sma_pos1',
 'y_max',
 'z_max',
 'x_min',
 'y_iqr',
 'z_iqr_pos1',
 'x_iqr',
 'z_max_pos1',
 'x_iqr_pos1',
 'xy_corr_pos1',
 'x_max_pos1',
 'xz_corr',
 'z_std_pos1',
 'z_min_pos1',
 'x_energy_pos1',
 'x_std_pos1',
 'yz_corr_pos1',
 'y_std',
 'z_std',
 'x_std',
 'xy_corr',
 'x_max',
 'z_iqr',
 'z_energy_pos1',
 'z_mean_pos1',
 'y_std_pos1',
 'height',
 'yz_corr',
 'y_energy_pos1']

# %% [markdown]
# ### Определение позиции

# %%
data = pd.read_csv('../datasets/added_pos1_metrics_windowed.csv', index_col=[0, 1])
data = data.reset_index(drop=True)
data = data.drop(['is_valid', 'age', 'sex'], axis=1)
data.head()
# Out:
#      x_mean       x_std    x_max    x_min      x_energy  x_iqr   y_mean  \
# 0  11156.76  123.532772  11380.0  10836.0  1.244884e+08  177.0  1158.80
# 1  11156.88  128.858961  11380.0  10836.0  1.244924e+08  193.0  1137.96
# 2  11154.36  134.410311  11532.0  10836.0  1.244376e+08  190.0  1088.32
# 3  10998.28  415.506022  11532.0   9384.0  1.211331e+08  323.0   853.36
# 4  10883.04  409.575930  11532.0   9384.0  1.186066e+08  543.0   537.68
#
#         y_std   y_max   y_min  ...  z_energy_pos1  x_iqr_pos1  y_iqr_pos1  \
# 0   73.172275  1348.0   920.0  ...   3.906659e+07       196.0       132.0
# 1   69.416023  1300.0   920.0  ...   3.906659e+07       196.0       132.0
# 2  171.829072  1380.0   164.0  ...   3.906659e+07       196.0       132.0
# 3  499.190851  1380.0 -1032.0  ...   3.906659e+07       196.0       132.0
# 4  622.192456  1380.0 -1032.0  ...   3.906659e+07       196.0       132.0
#
#    z_iqr_pos1  xy_corr_pos1  xz_corr_pos1  yz_corr_pos1  height  mass  \
# 0       485.0     -0.203383      0.750925     -0.452449     185    75
# 1       485.0     -0.203383      0.750925     -0.452449     185    75
# 2       485.0     -0.203383      0.750925     -0.452449     185    75
# 3       485.0     -0.203383      0.750925     -0.452449     185    75
# 4       485.0     -0.203383      0.750925     -0.452449     185    75
#
#    position
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#
# [5 rows x 47 columns]

# %%
y = data['position']
X = data.drop('position', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=1234
)

# %%
max_iter = 10000
C = 2

# %%
history = defaultdict(list)

# %%
for i in tqdm(range(5, len(sorted_metrics))):
    metrics = sorted_metrics[:i]
    
    X_test_cut = X_test[metrics].to_numpy()
    X_train_cut = X_train[metrics].to_numpy()
    
    scaler = StandardScaler().fit(X_train_cut)

    X_train_cut = scaler.transform(X_train_cut)
    
    svc = SVC(gamma='auto', C=C, decision_function_shape='ovo').fit(X_train_cut, y_train)
    
    time_predict = min(timeit.Timer('svc.predict(scaler.transform(X_test_cut[0, np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))

    y_pred = svc.predict(scaler.transform(X_test_cut))
    accuracy = accuracy_score(y_test, y_pred)
    
    history['time_predict'].append(time_predict)
    history['accuracy'].append(accuracy)
# Out:
# 100%|██████████| 41/41 [00:26<00:00,  1.53it/s]

# %%
plot_acc_and_time(history, sorted_metrics)

# %% [markdown]
# ### Определение горбатости в ходячем положении

# %%
data = pd.read_csv('../datasets/added_pos1_metrics_windowed.csv', index_col=[0, 1])
data = data.reset_index(drop=True)
data = data[data['position'] == 3].drop(['position', 'age'], axis=1)
data.head()
# Out:
#       x_mean        x_std    x_max   x_min      x_energy   x_iqr   y_mean  \
# 70  12685.04  2477.023409  22084.0  6396.0  1.669845e+08  3433.0  1969.00
# 71  12148.96  2494.978107  22084.0  6396.0  1.537599e+08  2141.0  1951.48
# 72  12151.88  3207.290657  25876.0  6396.0  1.578520e+08  2697.0  1784.28
# 73  12398.36  3620.581932  29072.0  6396.0  1.666969e+08  3260.0   753.16
# 74  12812.64  3791.848513  29072.0  8804.0  1.783981e+08  3707.0    97.68
#
#           y_std    y_max   y_min  ...  x_iqr_pos1  y_iqr_pos1  z_iqr_pos1  \
# 70  3074.250090  12488.0 -3760.0  ...       196.0       132.0       485.0
# 71  3311.899216  12488.0 -3760.0  ...       196.0       132.0       485.0
# 72  3319.946075  12488.0 -5016.0  ...       196.0       132.0       485.0
# 73  2951.146042  10968.0 -5704.0  ...       196.0       132.0       485.0
# 74  2808.045249   8604.0 -5844.0  ...       196.0       132.0       485.0
#
#     xy_corr_pos1  xz_corr_pos1  yz_corr_pos1  height  mass  is_valid  sex
# 70     -0.203383      0.750925     -0.452449     185    75         0    1
# 71     -0.203383      0.750925     -0.452449     185    75         0    1
# 72     -0.203383      0.750925     -0.452449     185    75         0    1
# 73     -0.203383      0.750925     -0.452449     185    75         0    1
# 74     -0.203383      0.750925     -0.452449     185    75         0    1
#
# [5 rows x 48 columns]

# %%
y = data['is_valid']
X = data.drop('is_valid', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=1234
)

# %%
max_iter = 10000
C = 2

history = defaultdict(list)

# %%
for i in tqdm(range(5, len(sorted_metrics))):
    metrics = sorted_metrics[:i]
    
    X_test_cut = X_test[metrics].to_numpy()
    X_train_cut = X_train[metrics].to_numpy()
    
    scaler = StandardScaler().fit(X_train_cut)

    X_train_cut = scaler.transform(X_train_cut)
    
    svc = SVC(gamma='auto', C=C).fit(X_train_cut, y_train)
    
    time_predict = min(timeit.Timer('svc.predict(scaler.transform(X_test_cut[0, np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))

    y_pred = svc.predict(scaler.transform(X_test_cut))
    accuracy = accuracy_score(y_test, y_pred)
    
    history['time_predict'].append(time_predict)
    history['accuracy'].append(accuracy)
# Out:
# 100%|██████████| 41/41 [00:03<00:00, 12.36it/s]

# %%
plot_acc_and_time(history, sorted_metrics)

# %% [markdown]
# ### Определение горбатости в сидячем положении

# %%
data = pd.read_csv('../datasets/added_pos1_metrics_windowed.csv', index_col=[0, 1])
data = data.reset_index(drop=True)
data = data[data['position'] == 1].drop(['position', 'age'], axis=1)
data.head()
# Out:
#      x_mean       x_std    x_max    x_min      x_energy  x_iqr   y_mean  \
# 0  11156.76  123.532772  11380.0  10836.0  1.244884e+08  177.0  1158.80
# 1  11156.88  128.858961  11380.0  10836.0  1.244924e+08  193.0  1137.96
# 2  11154.36  134.410311  11532.0  10836.0  1.244376e+08  190.0  1088.32
# 3  10998.28  415.506022  11532.0   9384.0  1.211331e+08  323.0   853.36
# 4  10883.04  409.575930  11532.0   9384.0  1.186066e+08  543.0   537.68
#
#         y_std   y_max   y_min  ...  x_iqr_pos1  y_iqr_pos1  z_iqr_pos1  \
# 0   73.172275  1348.0   920.0  ...       196.0       132.0       485.0
# 1   69.416023  1300.0   920.0  ...       196.0       132.0       485.0
# 2  171.829072  1380.0   164.0  ...       196.0       132.0       485.0
# 3  499.190851  1380.0 -1032.0  ...       196.0       132.0       485.0
# 4  622.192456  1380.0 -1032.0  ...       196.0       132.0       485.0
#
#    xy_corr_pos1  xz_corr_pos1  yz_corr_pos1  height  mass  is_valid  sex
# 0     -0.203383      0.750925     -0.452449     185    75         0    1
# 1     -0.203383      0.750925     -0.452449     185    75         0    1
# 2     -0.203383      0.750925     -0.452449     185    75         0    1
# 3     -0.203383      0.750925     -0.452449     185    75         0    1
# 4     -0.203383      0.750925     -0.452449     185    75         0    1
#
# [5 rows x 48 columns]

# %%
y = data['is_valid']
X = data.drop('is_valid', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=1234
)

max_iter = 10000
C = 2

history = defaultdict(list)

# %%
for i in tqdm(range(5, len(sorted_metrics))):
    metrics = sorted_metrics[:i]
    
    X_test_cut = X_test[metrics].to_numpy()
    X_train_cut = X_train[metrics].to_numpy()
    
    scaler = StandardScaler().fit(X_train_cut)

    X_train_cut = scaler.transform(X_train_cut)
    
    svc = SVC(gamma='auto', C=C).fit(X_train_cut, y_train)
    
    time_predict = min(timeit.Timer('svc.predict(scaler.transform(X_test_cut[0, np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))

    y_pred = svc.predict(scaler.transform(X_test_cut))
    accuracy = accuracy_score(y_test, y_pred)
    
    history['time_predict'].append(time_predict)
    history['accuracy'].append(accuracy)
# Out:
# 100%|██████████| 41/41 [00:02<00:00, 18.10it/s]

# %%
plot_acc_and_time(history, sorted_metrics)

# %% [markdown]
# ### Определение горбатости в стоячем положении

# %%
data = pd.read_csv('../datasets/added_pos1_metrics_windowed.csv', index_col=[0, 1])
data = data.reset_index(drop=True)
data = data[data['position'] == 2].drop(['position', 'age'], axis=1)
data.head()
# Out:
#       x_mean       x_std    x_max    x_min      x_energy  x_iqr  y_mean  \
# 44  12316.28  235.528208  12820.0  11556.0  1.517457e+08  315.0  -61.16
# 45  12299.04  235.876441  12820.0  11556.0  1.513215e+08  302.0   51.00
# 46  12331.88  277.328936  13052.0  11556.0  1.521514e+08  343.0  105.52
# 47  12427.68  283.239945  13052.0  11556.0  1.545267e+08  399.0   46.28
# 48  12539.80  257.864031  13052.0  11988.0  1.573124e+08  384.0   -1.24
#
#          y_std  y_max  y_min  ...  x_iqr_pos1  y_iqr_pos1  z_iqr_pos1  \
# 44  327.249348  960.0 -792.0  ...       196.0       132.0       485.0
# 45  352.250772  960.0 -792.0  ...       196.0       132.0       485.0
# 46  321.585858  960.0 -744.0  ...       196.0       132.0       485.0
# 47  361.610876  960.0 -892.0  ...       196.0       132.0       485.0
# 48  361.704023  696.0 -892.0  ...       196.0       132.0       485.0
#
#     xy_corr_pos1  xz_corr_pos1  yz_corr_pos1  height  mass  is_valid  sex
# 44     -0.203383      0.750925     -0.452449     185    75         0    1
# 45     -0.203383      0.750925     -0.452449     185    75         0    1
# 46     -0.203383      0.750925     -0.452449     185    75         0    1
# 47     -0.203383      0.750925     -0.452449     185    75         0    1
# 48     -0.203383      0.750925     -0.452449     185    75         0    1
#
# [5 rows x 48 columns]

# %%
y = data['is_valid']
X = data.drop('is_valid', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=1234
)

max_iter = 10000
C = 2

history = defaultdict(list)

# %%
for i in tqdm(range(5, len(sorted_metrics))):
    metrics = sorted_metrics[:i]
    
    X_test_cut = X_test[metrics].to_numpy()
    X_train_cut = X_train[metrics].to_numpy()
    
    scaler = StandardScaler().fit(X_train_cut)

    X_train_cut = scaler.transform(X_train_cut)
    
    svc = SVC(gamma='auto', C=C).fit(X_train_cut, y_train)
    
    time_predict = min(timeit.Timer('svc.predict(scaler.transform(X_test_cut[0, np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))

    y_pred = svc.predict(scaler.transform(X_test_cut))
    accuracy = accuracy_score(y_test, y_pred)
    
    history['time_predict'].append(time_predict)
    history['accuracy'].append(accuracy)
# Out:
# 100%|██████████| 41/41 [00:02<00:00, 13.69it/s]

# %%
plot_acc_and_time(history, sorted_metrics)

# %% [markdown]
# ### Определение горбатости без известной позиции

# %%
data = pd.read_csv('../datasets/added_pos1_metrics_windowed.csv', index_col=[0, 1])
data = data.reset_index(drop=True)
data = data.drop(['position', 'age'], axis=1)
data.head()
# Out:
#      x_mean       x_std    x_max    x_min      x_energy  x_iqr   y_mean  \
# 0  11156.76  123.532772  11380.0  10836.0  1.244884e+08  177.0  1158.80
# 1  11156.88  128.858961  11380.0  10836.0  1.244924e+08  193.0  1137.96
# 2  11154.36  134.410311  11532.0  10836.0  1.244376e+08  190.0  1088.32
# 3  10998.28  415.506022  11532.0   9384.0  1.211331e+08  323.0   853.36
# 4  10883.04  409.575930  11532.0   9384.0  1.186066e+08  543.0   537.68
#
#         y_std   y_max   y_min  ...  x_iqr_pos1  y_iqr_pos1  z_iqr_pos1  \
# 0   73.172275  1348.0   920.0  ...       196.0       132.0       485.0
# 1   69.416023  1300.0   920.0  ...       196.0       132.0       485.0
# 2  171.829072  1380.0   164.0  ...       196.0       132.0       485.0
# 3  499.190851  1380.0 -1032.0  ...       196.0       132.0       485.0
# 4  622.192456  1380.0 -1032.0  ...       196.0       132.0       485.0
#
#    xy_corr_pos1  xz_corr_pos1  yz_corr_pos1  height  mass  is_valid  sex
# 0     -0.203383      0.750925     -0.452449     185    75         0    1
# 1     -0.203383      0.750925     -0.452449     185    75         0    1
# 2     -0.203383      0.750925     -0.452449     185    75         0    1
# 3     -0.203383      0.750925     -0.452449     185    75         0    1
# 4     -0.203383      0.750925     -0.452449     185    75         0    1
#
# [5 rows x 48 columns]

# %%
y = data['is_valid']
X = data.drop('is_valid', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=1234
)

max_iter = 10000
C = 2

history = defaultdict(list)

# %%
for i in tqdm(range(5, len(sorted_metrics))):
    metrics = sorted_metrics[:i]
    
    X_test_cut = X_test[metrics].to_numpy()
    X_train_cut = X_train[metrics].to_numpy()
    
    scaler = StandardScaler().fit(X_train_cut)

    X_train_cut = scaler.transform(X_train_cut)
    
    svc = SVC(gamma='auto', C=C).fit(X_train_cut, y_train)
    
    time_predict = min(timeit.Timer('svc.predict(scaler.transform(X_test_cut[0, np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))

    y_pred = svc.predict(scaler.transform(X_test_cut))
    accuracy = accuracy_score(y_test, y_pred)
    
    history['time_predict'].append(time_predict)
    history['accuracy'].append(accuracy)
# Out:
# 100%|██████████| 41/41 [00:47<00:00,  1.16s/it]

# %%
plot_acc_and_time(history, sorted_metrics)

# %% [markdown]
# Исследование влияния размера окна на определения горбатости.

# %%
window_sizes = [50, 100, 150, 200]

# %%
max_iter = 10000
C = 2

# %%
accuracies = []
time_measurements = []

# %%
for window_size in window_sizes:
    load_path = '../datasets/added_pos1_metrics_windowed_' + str(window_size) + '.csv'
    data = pd.read_csv(load_path, index_col=[0, 1])
    data = data.reset_index(drop=True)
    data = data.drop(['position', 'age'], axis=1)
    
    y = data['is_valid']
    X = data.drop('is_valid', axis=1)[sorted_metrics[:10]]
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, train_size=0.7, random_state=1234
    )

    scaler = StandardScaler().fit(X_train)

    X_train = scaler.transform(X_train)
    
    svc = SVC(gamma='auto', C=C).fit(X_train, y_train)

    y_pred = svc.predict(scaler.transform(X_test))
    time_elapsed = min(timeit.Timer('svc.predict(scaler.transform(X_test.iloc[0].to_numpy()[np.newaxis]))', globals=globals()).repeat(repeat=100, number=1))
    
    time_measurements.append(time_elapsed)

    accuracy = accuracy_score(y_test, y_pred)
    accuracies.append(accuracy)
    
    print(f'window size: {window_size}, accuracy: {accuracy:.3f}, time: {time_elapsed} s')
# Out:
# window size: 50, accuracy: 0.955, time: 0.0003592690045479685 s
# window size: 100, accuracy: 0.947, time: 0.00028772299992851913 s
# window size: 150, accuracy: 0.957, time: 0.0002714780130190775 s
# window size: 200, accuracy: 0.941, time: 0.0002516519889468327 s
